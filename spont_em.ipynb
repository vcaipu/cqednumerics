# %%
import numpy as np

# %%
hbar = 1

# %%
def inner_product(phi_p,phi_m):
    # Compute X_R - X_L
    phi_l = 1/(np.sqrt(2)) * (phi_p - phi_m)
    phi_r = 1/(np.sqrt(2)) * (phi_p + phi_m)
# Out:
#   Cell In[3], line 4
#     phi_r =
#             ^
# SyntaxError: invalid syntax
